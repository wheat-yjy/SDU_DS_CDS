# %%
import os

# %%
print(os.listdir())
# Out:
# ['File_45.txt', 'File_34.txt', 'File_8.txt', 'File_12.txt', 'File_22.txt', 'File_11.txt', 'File_3.txt', 'File_5.txt', 'File_30.txt', 'File_19.txt', 'File_31.txt', 'File_24.txt', 'File_23.txt', 'File_44.txt', 'File_42.txt', 'File_37.txt', 'File_1.txt', 'File_39.txt', 'File_38.txt', '.ipynb_checkpoints', 'File_43.txt', 'File_7.txt', 'File_20.txt', 'File_40.txt', 'File_26.txt', 'File_41.txt', 'Untitled.ipynb', 'File_33.txt', 'loveyou', 'File_14.txt', 'File_17.txt', 'File_28.txt', 'File_13.txt', 'File_10.txt', 'File_32.txt', 'File_21.txt', 'File_36.txt', 'File_16.txt', 'File_6.txt', 'File_29.txt', 'File_25.txt', 'File_15.txt', 'File_35.txt', 'File_2.txt', 'File_18.txt', 'File_27.txt', 'File_4.txt', 'File_9.txt']

# %%
# ListElement {
#           name: "Bill Smith"
#       }
fileNames = os.listdir()
fileNames = set(fileNames)
fileNames = sorted(fileNames)
for file in fileNames:
    print("ListElement {\n\tname: " + "\"" + file + "\"" + "\n}")
# Out:
# ListElement {
# 	name: ".ipynb_checkpoints"
# }
# ListElement {
# 	name: "File_1.txt"
# }
# ListElement {
# 	name: "File_10.txt"
# }
# ListElement {
# 	name: "File_11.txt"
# }
# ListElement {
# 	name: "File_12.txt"
# }
# ListElement {
# 	name: "File_13.txt"
# }
# ListElement {
# 	name: "File_14.txt"
# }
# ListElement {
# 	name: "File_15.txt"
# }
# ListElement {
# 	name: "File_16.txt"
# }
# ListElement {
# 	name: "File_17.txt"
# }
# ListElement {
# 	name: "File_18.txt"
# }
# ListElement {
# 	name: "File_19.txt"
# }
# ListElement {
# 	name: "File_2.txt"
# }
# ListElement {
# 	name: "File_20.txt"
# }
# ListElement {
# 	name: "File_21.txt"
# }
# ListElement {
# 	name: "File_22.txt"
# }
# ListElement {
# 	name: "File_23.txt"
# }
# ListElement {
# 	name: "File_24.txt"
# }
# ListElement {
# 	name: "File_25.txt"
# }
# ListElement {
# 	name: "File_26.txt"
# }
# ListElement {
# 	name: "File_27.txt"
# }
# ListElement {
# 	name: "File_28.txt"
# }
# ListElement {
# 	name: "File_29.txt"
# }
# ...
